# %%
# Path.cwd() --> notebooks/
# .parent --> project root
# / "src" --> your actual source code
# sys.path.append() is telling Python to also look here when importing the modules

import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
SRC_PATH = PROJECT_ROOT / "src"

sys.path.append(str(SRC_PATH))

# %%
from fits_io import load_fits

# %%
# path name
fits_image_filename = "../data/raw/M51_01.fits"

# two return variables for the function
image_data, header_info = load_fits(fits_image_filename)

# outputs
print("\nShape: ", image_data.shape)
print("Dtype: ", image_data.dtype)
print("Min / Max: ", image_data.min(), " : ", image_data.max())
print("Exposure Time: ", header_info.get("EXPTIME"))
# Out:
# Filename: ../data/raw/M51_01.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU    1762   (8600, 12200)   float32
# None
# float32
# ...

# %%
# Understanding FITS header data for scientific context:
print(header_info["TELESCOP"]) # HST: Hubble Space Telescope
print(header_info["INSTRUME"]) # ACS: idenitifier for instrument used (Advanced Camera for Surveys)
print(header_info["DATE-OBS"]) # Date observed: 2005-01-20
print(header_info["OBJECT"])   # Object observed: Whirlpool Galaxy M51
print(header_info["EXPTIME"])  # Exposure time: how long hubble looked at the object in seconds (around 4 and a half hours of exposure)
# Out:
# HST
# ACS
# 2005-01-20
# Whirlpool Galaxy M51 in B
# 16320.0

# %%
# highly skewed histogram
import matplotlib.pyplot as plt

plt.hist(image_data.flatten(), bins=200)
plt.title("Pixel Intensity Distribution")
plt.show()
